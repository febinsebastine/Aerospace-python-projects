# %%
import numpy as np
import matplotlib.pyplot as plt
from astropy import units as u
from specutils.spectra import Spectrum1D
from specutils.fitting import fit_generic_continuum

# Step 1: Generate Random Spectra
np.random.seed(0)
x = np.linspace(0., 10., 200)
y = 3 * np.exp(-0.5 * (x - 6.3)**2 / 0.8**2) + np.random.normal(0., 0.2, x.shape)
spectra = Spectrum1D(flux=y * u.Jy, spectral_axis=x * u.um)

# Step 2: Apply Continuum Fitting
continuum_fit = fit_generic_continuum(spectra)
y_continuum_fit = continuum_fit(x * u.um)

# Step 3: Plot the Original Spectrum and Fitted Continuum
plt.figure(figsize=(8, 5))
plt.plot(x, y, label="Original Spectrum", color='blue', alpha=0.6)
plt.plot(x, y_continuum_fit, label="Fitted Continuum", color='red', linestyle="--")

# Customize and Display the Plot
plt.title("Continuum Fitting Using Specutils")
plt.xlabel("Wavelength (µm)")
plt.ylabel("Flux (Jy)")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# WARNING: Model is linear in parameters; consider using linear fitting methods. [astropy.modeling.fitting]
